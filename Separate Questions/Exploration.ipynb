# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter

# %%
movies = pd.read_csv("movie_data.csv")

# %% [markdown]
# Dataset column 'genres' is a string of what once appeared to be a list. genre_cleaner transforms this string into an actual list.

# %%
def genre_cleaner(row):
    genre_string = row['genres']
    genre_string = genre_string.replace(',','').replace('"','')
    #We lower just in case there is variability in capatalization convention
    genre_list = genre_string.strip("[]").lower().split()
    return genre_list

#Here we reassign genre column. We change the original dataset as there is no reason to keep old format
movies['genres'] = movies.apply(lambda row: genre_cleaner(row), axis = 1)

# %%
print(movies.isnull().sum())
print("...",len(movies))
# Out:
# id                        0
# title                     0
# release_date           2618
# box_office_revenue    34617
# runtime                6624
# genres                    0
# summary                   0
# dtype: int64
# ... 42204

# %% [markdown]
# Here we see that we have an enormous amount of genres, many of which are for all intents and purposes the same genre just spelled slightly differently. E.g. - "Educational" and "Education", or "Children's" and "Children's/Family".
#
# We must find a way to aggregate genres appropriately. Though it is important to note we will still have a large number of genres which I believe is justified.

# %%
genres_list = [genre for genres in movies['genres'] for genre in genres]

unique_genres = list(set(genres_list))
len(unique_genres)
# Out:
# 386

# %% [markdown]
# We now explore the frequency of each genre and basic statistcs of the counts

# %%
genre_counts = Counter(genres_list)
genre_counts_bar = sum(genre_counts.values())/len(genre_counts)

sum_squares = 0
for genre, count in genre_counts.items():
    sum_squares += (count - genre_counts_bar)**2
std_dev = np.sqrt(sum_squares/len(genre_counts))

print("Standard Deviation: ", std_dev)
print("Mean: ", genre_counts_bar)
print("Max: ", max(genre_counts.values()))
print("Min: ", min(genre_counts.values()))

# genre_counts.most_common(100)
# Out:
# Standard Deviation:  2228.19194216
# Mean:  560.6813471502591
# Max:  24641
# Min:  1

# %% [markdown]
# We will use unique_genres to create a mapping that will be used to combine like-genres into single categories.

# %%
fuzz.partial_ratio("family", "family-oriented")
# Out:
# 100

# %%
genre_mapper = {genre : [] for genre in unique_genres}

for i in range(len(unique_genres)):
    for j in range(len(unique_genres)):
        if i != j:
            ratio_score = fuzz.ratio(unique_genres[i],unique_genres[j])
            partial_score = fuzz.partial_ratio(unique_genres[i],unique_genres[j])
            if ratio_score >= 85 or partial_score == 100:
                genre_mapper[unique_genres[i]].append(unique_genres[j])
genre_mapper
# Out:
# {'&': [],
#  '95': [],
#  '[feature': ['[feature]', 'feature'],
#  '[feature]': ['[feature', 'feature'],
#  '\\u00e0': [],
#  'about': ['out'],
#  'absurdism': [],
#  'acid': [],
#  'action': ['action/adventure'],
#  'action/adventure': ['action', 'adventure'],
#  'adaptation': [],
#  'addiction': [],
#  'adult': [],
#  'adventure': ['action/adventure'],
#  'age': ['marriage', 'tragedy', 'language', 'coming-of-age', 'backstage'],
#  'airplanes': [],
#  'airports': [],
#  'albino': ['in'],
#  'alien': [],
#  'americana': [],
#  'and': ['stand-up',
#   'sandal',
#   'candid',
#   'propaganda',
#   'black-and-white',
#   'gland',
#   'netherlands'],
#  'animal': ['animals'],
#  'animals': ['animal'],
#  'animated': [],
#  'animation': [],
#  'anime': [],
#  'anthology': ['anthropology'],
#  'anthropology': ['anthology'],
#  'anti-war': ['war'],
#  'apocalyptic': ['post-apocalyptic'],
#  'applied': [],
#  'archaeology': [],
#  'archives': [],
#  'art': ['party', 'arts', 'cartoon', 'martial'],
#  'arts': ['art'],
#  'auto': [],
#  'avant-garde': [],
#  'b-movie': ['movie', 'c-movie'],
#  'b-western': ['western'],
#  'backstage': ['age'],
#  'baseball': [],
#  'beach': [],
#  'bengali': [],
#  'bias': [],
#  'biker': [],
#  'biographical': ['graphic'],
#  'biography': [],
#  'biopic': [],
#  'black': ['black-and-white'],
#  'black-and-white': ['black', 'and'],
#  'blaxploitation': ['exploitation'],
#  'bloopers': [],
#  'bollywood': ['tollywood', 'hollywood'],
#  'boxing': ['in'],
#  'breakdance': ['dance'],
#  'british': [],
#  'bruceploitation': [],
#  'buddy': [],
#  'business': ['in'],
#  'c-movie': ['movie', 'b-movie'],
#  'camera': [],
#  'camp': [],
#  'candid': ['and'],
#  'caper': [],
#  'cartoon': ['art'],
#  'cavalry': [],
#  'chase': [],
#  'chick': [],
#  'child': ["children's/family", "children's", 'childhood'],
#  'childhood': ['child'],
#  "children's": ["children's/family", 'child'],
#  "children's/family": ['child', 'family', "children's"],
#  'chinese': ['in'],
#  'christian': [],
#  'christmas': [],
#  'cinema': ['in'],
#  'clay': [],
#  'clef': [],
#  'cold': [],
#  'combat': [],
#  'comdedy': ['comedy'],
#  'comedies': [],
#  'comedy': ['tragicomedy', 'comdedy', 'comedy-drama'],
#  'comedy-drama': ['drama', 'comedy'],
#  'coming': ['in', 'coming-of-age'],
#  'coming-of-age': ['coming', 'age', 'in', 'of'],
#  'company': [],
#  'computer': ['computers'],
#  'computers': ['computer'],
#  'concert': [],
#  'conspiracy': [],
#  'cop': [],
#  'costume': [],
#  'courtroom': [],
#  'cowboy': [],
#  'creature': [],
#  'crime': [],
#  'criminal': ['in'],
#  'cult': ['culture'],
#  'culture': ['cult'],
#  'cyberpunk': ['punk'],
#  'czechoslovak': ['z'],
#  'dance': ['breakdance'],
#  'delinquency': ['in'],
#  'demonic': [],
#  'detective': [],
#  'disabilities': [],
#  'disaster': [],
#  'docudrama': ['drama'],
#  'documentaries': [],
#  'documentary': ['mockumentary', 'documetary', 'rockumentary'],
#  'documetary': ['documentary'],
#  'dogme': [],
#  'domestic': [],
#  'doomsday': [],
#  'drama': ['melodrama', 'docudrama', 'comedy-drama'],
#  'dystopia': ['stop'],
#  'ealing': ['in'],
#  'early': [],
#  'education': ['educational'],
#  'educational': ['education'],
#  'effort': [],
#  'eiga': [],
#  'empire': [],
#  'ensemble': [],
#  'entertainment': ['in'],
#  'environmental': [],
#  'epic': [],
#  'erotic': ['erotica', 'homoeroticism'],
#  'erotica': ['erotic'],
#  'errors': [],
#  'escape': [],
#  'essay': [],
#  'existentialism': [],
#  'experimental': [],
#  'exploitation': ['sexploitation', 'blaxploitation'],
#  'expressionism': [],
#  'extreme': [],
#  'fairy': [],
#  'family': ["children's/family", 'family-oriented'],
#  'family-oriented': ['family'],
#  'fan': ['fantasy', 'fantasies'],
#  'fantasies': ['fan'],
#  'fantasy': ['fan'],
#  'feature': ['[feature', '[feature]'],
#  'female': [],
#  'feminist': ['in'],
#  'fi': ['fictional',
#   'filmed',
#   'films',
#   'filipino',
#   'finance',
#   'film',
#   'sci-fi',
#   'fiction',
#   'fitness',
#   'film-opera'],
#  'fiction': ['fictional', 'fi'],
#  'fictional': ['fi', 'fiction'],
#  'filipino': ['fi', 'in'],
#  'film': ['fi', 'filmed', 'films', 'film-opera'],
#  'film-opera': ['fi', 'opera', 'film'],
#  'filmed': ['fi', 'film'],
#  'films': ['fi', 'film'],
#  'finance': ['fi', 'in'],
#  'fitness': ['fi'],
#  'flick': [],
#  'foreign': [],
#  'future': [],
#  'gangster': [],
#  'gay': [],
#  'gender': [],
#  'giallo': [],
#  'gladiators': [],
#  'glamorized': ['z'],
#  'gland': ['and'],
#  'goat': [],
#  'gothic': [],
#  'graphic': ['biographical', 'pornographic'],
#  'gross': ['gross-out'],
#  'gross-out': ['gross', 'out'],
#  'gulf': [],
#  'hagiography': [],
#  'hardcore': [],
#  'haunted': [],
#  'health': [],
#  'heaven-can-wait': [],
#  'heavenly': [],
#  'heist': [],
#  'hip': ['relationships'],
#  'historical': [],
#  'history': ['story'],
#  'holiday': [],
#  'hollywood': ['bollywood', 'tollywood'],
#  'homoeroticism': ['erotic'],
#  'hop': [],
#  'horror': ['road-horror'],
#  'horse': [],
#  'house': [],
#  'humour': [],
#  'hybrid': [],
#  'ii': [],
#  'illnesses': [],
#  'in': ['albino',
#   'racing',
#   'entertainment',
#   'instrumental',
#   'latino',
#   'investing',
#   'linguistics',
#   'boxing',
#   'singing',
#   'inspirational',
#   'coming',
#   'chinese',
#   'pinku',
#   'filipino',
#   'ealing',
#   'finance',
#   'point',
#   'business',
#   'cinema',
#   'interest',
#   'interpersonal',
#   'indie',
#   'invasion',
#   'original',
#   'innovations',
#   'sink',
#   'inventions',
#   'coming-of-age',
#   'delinquency',
#   'indian',
#   'ninja',
#   'feminist',
#   'therimin',
#   'criminal'],
#  'indian': ['in'],
#  'indie': ['in'],
#  'innovations': ['in'],
#  'inspirational': ['in'],
#  'instrumental': ['in'],
#  'interest': ['in'],
#  'interpersonal': ['in', 'personal'],
#  'invasion': ['in'],
#  'inventions': ['in'],
#  'investing': ['in'],
#  'issues': [],
#  'japanese': [],
#  'journalism': [],
#  'jukebox': [],
#  'jungle': [],
#  'juvenile': [],
#  'kafkaesque': [],
#  'kitchen': [],
#  'language': ['age'],
#  'latino': ['in'],
#  'law': ['outlaw'],
#  'legal': [],
#  'legion': [],
#  'lgbt': [],
#  'librarians': [],
#  'libraries': [],
#  'life': [],
#  'linguistics': ['in'],
#  'literature': [],
#  'live': [],
#  'malayalam': [],
#  'manners': [],
#  'marriage': ['age'],
#  'martial': ['art'],
#  'master': [],
#  'media': [],
#  'medical': [],
#  'melodrama': ['drama'],
#  'military': [],
#  'mockumentary': ['documentary', 'rockumentary'],
#  'mondo': [],
#  'monster': [],
#  'motion': [],
#  'movie': ['c-movie', 'b-movie', 'movies'],
#  'movies': ['movie'],
#  'mumblecore': [],
#  'music': ['musical'],
#  'musical': ['music'],
#  'mystery': [],
#  'mythological': [],
#  'natural': ['supernatural'],
#  'nature': [],
#  'neo-noir': ['noir'],
#  'neorealism': ['realism'],
#  'netherlands': ['the', 'and'],
#  'new': ['news'],
#  'news': ['new'],
#  'ninja': ['in'],
#  'noir': ['neo-noir'],
#  'northern': ['the'],
#  'nuclear': [],
#  'of': ['softcore', 'coming-of-age'],
#  'opera': ['film-opera'],
#  'operetta': [],
#  'original': ['in'],
#  'out': ['gross-out', 'about', 'outlaw'],
#  'outlaw': ['out', 'law'],
#  'parkour': [],
#  'parody': [],
#  'party': ['art'],
#  'patriotic': [],
#  'period': [],
#  'personal': ['interpersonal'],
#  'picture': ['pictures'],
#  'pictures': ['picture'],
#  'piece': [],
#  'pinku': ['in'],
#  'plague': [],
#  'play': [],
#  'point': ['in'],
#  'political': [],
#  'popular': [],
#  'porn': ['pornography', 'pornographic'],
#  'pornographic': ['pornography', 'graphic', 'porn'],
#  'pornography': ['pornographic', 'porn'],
#  'post-apocalyptic': ['apocalyptic'],
#  'pre-code': [],
#  'prison': [],
#  'private': [],
#  'problem': [],
#  'propaganda': ['and'],
#  'psycho-biddy': [],
#  'psychological': [],
#  'punk': ['steampunk', 'cyberpunk'],
#  'queer': [],
#  'race': [],
#  'racing': ['in'],
#  'rape': [],
#  'realism': ['surrealism', 'neorealism'],
#  'reboot': [],
#  'records': [],
#  'relationships': ['hip'],
#  'release': [],
#  'religious': [],
#  'remake': [],
#  'revenge': [],
#  'revisionist': [],
#  'road': ['roadshow/carny', 'roadshow', 'road-horror'],
#  'road-horror': ['horror', 'road'],
#  'roadshow': ['roadshow/carny', 'road'],
#  'roadshow/carny': ['road', 'roadshow'],
#  'rock': ['rockumentary'],
#  'rockumentary': ['rock', 'mockumentary', 'documentary'],
#  'romance': [],
#  'romantic': [],
#  'samurai': [],
#  'sandal': ['and'],
#  'satire': [],
#  'school': [],
#  'sci': ['science', 'sci-fi'],
#  'sci-fi': ['fi', 'sci'],
#  'science': ['sci'],
#  'screwball': [],
#  'serial': [],
#  'sex': ['sexploitation'],
#  'sexploitation': ['sex', 'exploitation'],
#  'short': ['shot'],
#  'shot': ['short'],
#  'silent': [],
#  'silhouette': [],
#  'singing': ['in'],
#  'sink': ['in'],
#  'slapstick': [],
#  'slasher': [],
#  'slice': [],
#  'social': [],
#  'society': [],
#  'softcore': ['of'],
#  'sorcery': [],
#  'space': [],
#  'spaghetti': [],
#  'splatter': [],
#  'sponsored': [],
#  'sports': [],
#  'spy': [],
#  'stand-up': ['and'],
#  'star': [],
#  'statutory': [],
#  'steampunk': ['punk'],
#  'stoner': [],
#  'stop': ['dystopia'],
#  'story': ['history'],
#  'studies': [],
#  'superhero': [],
#  'supermarionation': [],
#  'supernatural': ['natural'],
#  'surrealism': ['realism'],
#  'suspense': [],
#  'swashbuckler': [],
#  'sword': [],
#  'tale': [],
#  'tamil': [],
#  'teen': [],
#  'television': [],
#  'the': ['northern', 'themed', 'theatrical', 'netherlands', 'therimin'],
#  'theatrical': ['the'],
#  'themed': ['the'],
#  'therimin': ['the', 'in'],
#  'thriller': ['thrillers'],
#  'thrillers': ['thriller'],
#  'time': [],
#  'tokusatsu': [],
#  'tollywood': ['bollywood', 'hollywood'],
#  'tragedy': ['age'],
#  'tragicomedy': ['comedy'],
#  'travel': [],
#  'vampire': [],
#  'vehicle': [],
#  'view': [],
#  'war': ['warfare', 'anti-war'],
#  'warfare': ['war'],
#  'wave': [],
#  'werewolf': [],
#  'western': ['b-western'],
#  'whodunit': [],
#  'women': [],
#  'workplace': [],
#  'world': [],
#  'wuxia': [],
#  'z': ['glamorized', 'czechoslovak', 'zombie'],
#  'zombie': ['z']}

# %%
movies['genres'][0]
# Out:
# ['space',
#  'western',
#  'horror',
#  'supernatural',
#  'thriller',
#  'science',
#  'fiction',
#  'action',
#  'adventure']

# %%
genre_dict = {}
for i in range(len(movies)):
    current_movie = movies.iloc[i]
    title = current_movie['title']
    revenue = current_movie['box_office_revenue']
    summary = current_movie['summary']
    genres = current_movie['genres']
    
    for genre in genres:
        if len(genre_dict[genre]) < 1:
            genre_dict[genre] = []
            genre_dict[genre].append((title, revenue, summary))
        else:
            genre_dict[genre].append((title, revenue, summary))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-8f2fc28584f9> in <module>()
#       8
#       9     for genre in genres:
# ---> 10         if len(genre_dict[genre]) < 1:
#      11             genre_dict[genre] = []
#      12             genre_dict[genre].append((title, revenue, summary))
#
# KeyError: 'space'

# %%
movies
# Out:
#           id                                              title release_date  \
# 0          0                                     Ghosts of Mars   2001-08-24
# 1          1                                   White Of The Eye         1987
# 2          2                                  A Woman in Flames         1983
# 3          3                          The Sorcerer's Apprentice         2002
# 4          4                                        Little city   1997-04-04
# 5          5                                            Henry V   1989-11-08
# 6          6                                       Aaah Belinda         1986
# 7          7                            The Mechanical Monsters          NaN
# 8          8                                       Mary Poppins   1964-08-27
# 9          9                           Die Fahne von Kriwoj Rog         1967
# 10        10                                      White on Rice         2009
# 11        11                                        Anbu Thozhi   2007-08-17
# 12        12                                           Baby Boy   2001-06-27
# 13        13                                   Bindiya Chamkegi   1984-01-20
# 14        14                                           Vandanam         1989
# 15        15                                      Anokha Rishta         1986
# 16        16                       Karayilekku Oru Kadal Dooram   2010-12-31
# 17        17                                        Siam Sunset         1999
# 18        18                                        Kausthubham   2010-03-19
# 19        19                Archie: To Riverdale and Back Again   1990-05-06
# 20        20                                             Troops         1997
# 21        21                                     Daddy and Them         2001
# 22        22                             The Gods Must Be Crazy         1980
# 23        23                                       Rudo y Cursi         2008
# 24        24                        Kinjite: Forbidden Subjects         1989
# 25        25                            The Great New Wonderful   2006-06-23
# 26        26                                           Loverboy   1989-04-28
# 27        27                                      Chandra Mukhi   1993-10-22
# 28        28                                             Juarez         1939
# 29        29                  Chasing Ghosts: Beyond the Arcade         2007
# ...      ...                                                ...          ...
# 42174  42174                                             Vajram         2004
# 42175  42175                                    Eternally Yours   1939-10-07
# 42176  42176                        Confessions of a Sexist Pig   1998-03-07
# 42177  42177                                   Producing Adults         2004
# 42178  42178            Sherlock Holmes and the Voice of Terror   1942-09-18
# 42179  42179                               Desperate Characters         1971
# 42180  42180                                  The Leopard Woman          NaN
# 42181  42181                                              Wilde         1997
# 42182  42182                                  Coming to America   1988-06-29
# 42183  42183                    The Brother from Another Planet   1984-09-07
# 42184  42184                                        Inspiration   1931-01-31
# 42185  42185                                       Pokkiri Raja   2010-05-07
# 42186  42186                                         Mondo Cane         1962
# 42187  42187                                          The Trial   2009-07-08
# 42188  42188                                           Dot.Kill         2005
# 42189  42189                                      Boy Meets Dog   1938-03-10
# 42190  42190                                             Mirage         1972
# 42191  42191                                    Spaced Invaders         1990
# 42192  42192                                 The Flying Serpent         1946
# 42193  42193                                        Kalai Arasi   1963-04-19
# 42194  42194                                     State and Main   2000-08-26
# 42195  42195                                      Guilty as Sin   1993-06-04
# 42196  42196                                    Into the Mirror   2003-08-14
# 42197  42197                                        Gopi Kishan   1994-12-02
# 42198  42198                                     Eşrefpaşalılar   2010-03-05
# 42199  42199                                    The Ghost Train   1941-05-03
# 42200  42200                           Mermaids: The Body Found   2011-03-19
# 42201  42201                                            Knuckle   2011-01-21
# 42202  42202  The Super Dimension Fortress Macross II: Lover...   1992-05-21
# 42203  42203                                            Spliced         2002
#
#        box_office_revenue  runtime  \
# 0              14010832.0     98.0
# 1                     NaN    110.0
# 2                     NaN    106.0
# 3                     NaN     86.0
# 4                     NaN     93.0
# 5              10161099.0    137.0
# 6                     NaN      NaN
# 7                     NaN      NaN
# 8             102272727.0    139.0
# 9                     NaN    108.0
# 10                    NaN     82.0
# 11                    NaN      NaN
# 12             29381649.0    123.0
# 13                    NaN      NaN
# 14                    NaN    168.0
# 15                    NaN    180.0
# 16                    NaN    110.0
# 17                    NaN     91.0
# 18                    NaN      NaN
# 19                    NaN    100.0
# 20                    NaN     10.0
# 21                    NaN    101.0
# 22             34331783.0    109.0
# 23             11091868.0    103.0
# 24              3416846.0     97.0
# 25               172055.0     87.0
# 26              3960327.0     98.0
# 27                    NaN      NaN
# 28                    NaN    125.0
# 29                    NaN     90.0
# ...                   ...      ...
# 42174                 NaN      NaN
# 42175            683131.0     91.0
# 42176                 NaN     91.0
# 42177                 NaN    100.0
# 42178                 NaN     66.0
# 42179                 NaN     97.0
# 42180                 NaN     70.0
# 42181           2158775.0    118.0
# 42182         288752301.0    117.0
# 42183                 NaN    104.0
# 42184                 NaN     74.0
# 42185                 NaN    136.0
# 42186                 NaN    108.0
# 42187                 NaN     72.0
# 42188                 NaN     90.0
# 42189                 NaN      9.0
# 42190                 NaN     82.0
# 42191          15369573.0    100.0
# 42192                 NaN     59.0
# 42193                 NaN      NaN
# 42194           6944471.0    106.0
# 42195          22886222.0    107.0
# 42196                 NaN    113.0
# 42197                 NaN      NaN
# 42198           1847671.0      NaN
# 42199                 NaN     82.0
# 42200                 NaN    120.0
# 42201                 NaN     96.0
# 42202                 NaN    150.0
# 42203                 NaN     86.0
#
#                                                   genres  \
# 0      [space, western, horror, supernatural, thrille...
# 1      [erotic, thriller, psychological, thriller, th...
# 2                                                [drama]
# 3      [adventure, fantasy, world, cinema, family, film]
# 4      [romance, film, ensemble, film, comedy-drama, ...
# 5      [epic, war, film, costume, drama, drama, perio...
# 6                                               [comedy]
# 7      [short, film, science, fiction, family, film, ...
# 8      [children's/family, children's, fantasy, comed...
# 9                                                     []
# 10      [romance, film, comedy, indie, romantic, comedy]
# 11                                       [romance, film]
# 12              [coming, of, age, crime, fiction, drama]
# 13                                [comedy, family, film]
# 14                                              [action]
# 15     [romance, film, musical, drama, bollywood, wor...
# 16                                               [drama]
# 17     [romance, film, comedy, indie, romantic, comed...
# 18                                               [drama]
# 19                                              [comedy]
# 20                       [indie, fan, film, short, film]
# 21                               [comedy, black, comedy]
# 22     [adventure, comedy, indie, cult, slapstick, co...
# 23     [comedy, comedy-drama, sports, drama, family, ...
# 24     [crime, fiction, action/adventure, action, thr...
# 25          [indie, ensemble, film, drama, comedy-drama]
# 26             [romance, film, comedy, romantic, comedy]
# 27                                [romance, film, drama]
# 28     [costume, drama, biopic, [feature], black-and-...
# 29         [documentary, culture, &, society, biography]
# ...                                                  ...
# 42174                                    [drama, action]
# 42175  [romance, film, black-and-white, family, drama...
# 42176                         [comedy, romantic, comedy]
# 42177  [comedy-drama, gay, interest, drama, romantic,...
# 42178  [detective, fiction, black-and-white, crime, t...
# 42179         [drama, marriage, drama, film, adaptation]
# 42180                      [romance, film, silent, film]
# 42181  [romance, film, gay, interest, biographical, f...
# 42182  [romance, film, comedy, of, manners, comedy, d...
# 42183  [romance, film, fantasy, comedy, indie, cult, ...
# 42184                           [black-and-white, drama]
# 42185                                            [drama]
# 42186  [documentary, world, cinema, horror, culture, ...
# 42187                                      [documentary]
# 42188  [crime, thriller, action/adventure, action, ps...
# 42189                                      [short, film]
# 42190                             [drama, world, cinema]
# 42191  [comedy, science, fiction, adventure, alien, f...
# 42192                        [b-movie, horror, thriller]
# 42193   [romance, film, drama, science, fiction, action]
# 42194                        [comedy, americana, parody]
# 42195  [erotic, thriller, courtroom, drama, crime, th...
# 42196                                           [horror]
# 42197                     [comedy, crime, drama, action]
# 42198                              [comedy, film, drama]
# 42199   [comedy, supernatural, crime, fiction, thriller]
# 42200                                            [drama]
# 42201           [documentary, drama, biographical, film]
# 42202  [drama, japanese, movies, short, film, anime, ...
# 42203                  [teen, horror, slasher, thriller]
#
#                                                  summary
# 0      Set in the second half of the 22nd century, th...
# 1      A series of murders of rich young women throug...
# 2      Eva, an upper class housewife, becomes frustra...
# 3      Every hundred years, the evil Morgana  returns...
# 4      Adam, a San Francisco-based artist who works a...
# 5      {{Plot|dateAct 1Act 2Act 3Act 4Act 5 Finally n...
# 6      Serap, a young actress with a strong, lively p...
# 7       The story starts as one of the robots flies i...
# 8      The film opens with Mary Poppins  perched in a...
# 9      Otto Brosowski, a communist miner, writes to t...
# 10     Jimmy ([[Hiroshi Watanabe  loves dinosaurs and...
# 11     The film opens with a simpleton from a small v...
# 12     A young 20-year-old named Jody  lives with his...
# 13     Shalini 'Shalu' lives a wealthy lifestyle with...
# 14     Professor Kurian Fernandez , a convict escapes...
# 15     Mary, an orphan lives in an orphanage run by n...
# 16     Anoop Chandran , is a famous writer and award ...
# 17     Perry is an English chemist working for a pain...
# 18     The film is the story of Yamuna  whose life is...
# 19     Archie Andrews, fifteen years after graduating...
# 20     An example of the film's comedic tone comes in...
# 21     Ruby and Claude Montgomery are a very insecure...
# 22     The film is a collision of three separate stor...
# 23     In the fictional farming village of Tlachtlán,...
# 24     A Japanese businessman sees a woman being grop...
# 25     The Great New Wonderful is a series of vignett...
# 26     Randy Bodek  is a rebellious college slacker, ...
# 27     Chandra Mukhi , a princess of a heavenly kingd...
# 28     The film focuses on the conflict between Maxim...
# 29     In the 1980s, video games were synonymous with...
# ...                                                  ...
# 42174  Vajram movie is about Devarajan , a Mafioso tu...
# 42175  Anital Halstead  goes to see a magic act perfo...
# 42176  A daytime soap opera star has to deal with his...
# 42177  The film deals with the myriad complications a...
# 42178  The film begins with a title card describing H...
# 42179  Sophie and Otto Bentwood are a middle-aged, mi...
# 42180  The story is set in Africa. Two rival European...
# 42181  The film opens with Oscar Wilde's 1882 visit t...
# 42182  Akeem Joffer , the prince and heir to the thro...
# 42183  Joe Morton stars in this dramatic comedy, set ...
# 42184  Yvonne Valbret  is a Parisian belle who poses ...
# 42185  The film revolves around Madhavan Nair who unk...
# 42186  At the beginning, there is a scene with a dog ...
# 42187  In September 1998, at the end of the Balkan wa...
# 42188  Charlie Daines , is a morphine-addicted detect...
# 42189  The story begins with young Bobby and his frie...
# 42190  A story about a young man who inherits a broke...
# 42191  The space armada from Mars, known as the Imper...
# 42192  Insane archaeologist Professor Andrew Forbes  ...
# 42193  Kalai Arasi' is a well-blended story of romanc...
# 42194  Havoc is wrought on the inhabitants of a small...
# 42195  Jennifer Haines  is an up-and-coming Chicago a...
# 42196  After accidentally causing the death of his pa...
# 42197  Kishan  killed a man in his childhood when the...
# 42198  The film is about two friends, Tayyar , a mafi...
# 42199  {{plot}} The film opens with a Great Western e...
# 42200  Two former National Oceanic Atmospheric Admini...
# 42201  {{No plot}} This film follows 12 years in the ...
# 42202  The story takes place in the year 2092,The Sup...
# 42203  The movie is about a teenage girl who loves ho...
#
# [42204 rows x 7 columns]

# %%
movies
# Out:
#           id                                              title release_date  \
# 0          0                                     Ghosts of Mars   2001-08-24
# 1          1                                   White Of The Eye         1987
# 2          2                                  A Woman in Flames         1983
# 3          3                          The Sorcerer's Apprentice         2002
# 4          4                                        Little city   1997-04-04
# 5          5                                            Henry V   1989-11-08
# 6          6                                       Aaah Belinda         1986
# 7          7                            The Mechanical Monsters          NaN
# 8          8                                       Mary Poppins   1964-08-27
# 9          9                           Die Fahne von Kriwoj Rog         1967
# 10        10                                      White on Rice         2009
# 11        11                                        Anbu Thozhi   2007-08-17
# 12        12                                           Baby Boy   2001-06-27
# 13        13                                   Bindiya Chamkegi   1984-01-20
# 14        14                                           Vandanam         1989
# 15        15                                      Anokha Rishta         1986
# 16        16                       Karayilekku Oru Kadal Dooram   2010-12-31
# 17        17                                        Siam Sunset         1999
# 18        18                                        Kausthubham   2010-03-19
# 19        19                Archie: To Riverdale and Back Again   1990-05-06
# 20        20                                             Troops         1997
# 21        21                                     Daddy and Them         2001
# 22        22                             The Gods Must Be Crazy         1980
# 23        23                                       Rudo y Cursi         2008
# 24        24                        Kinjite: Forbidden Subjects         1989
# 25        25                            The Great New Wonderful   2006-06-23
# 26        26                                           Loverboy   1989-04-28
# 27        27                                      Chandra Mukhi   1993-10-22
# 28        28                                             Juarez         1939
# 29        29                  Chasing Ghosts: Beyond the Arcade         2007
# ...      ...                                                ...          ...
# 42174  42174                                             Vajram         2004
# 42175  42175                                    Eternally Yours   1939-10-07
# 42176  42176                        Confessions of a Sexist Pig   1998-03-07
# 42177  42177                                   Producing Adults         2004
# 42178  42178            Sherlock Holmes and the Voice of Terror   1942-09-18
# 42179  42179                               Desperate Characters         1971
# 42180  42180                                  The Leopard Woman          NaN
# 42181  42181                                              Wilde         1997
# 42182  42182                                  Coming to America   1988-06-29
# 42183  42183                    The Brother from Another Planet   1984-09-07
# 42184  42184                                        Inspiration   1931-01-31
# 42185  42185                                       Pokkiri Raja   2010-05-07
# 42186  42186                                         Mondo Cane         1962
# 42187  42187                                          The Trial   2009-07-08
# 42188  42188                                           Dot.Kill         2005
# 42189  42189                                      Boy Meets Dog   1938-03-10
# 42190  42190                                             Mirage         1972
# 42191  42191                                    Spaced Invaders         1990
# 42192  42192                                 The Flying Serpent         1946
# 42193  42193                                        Kalai Arasi   1963-04-19
# 42194  42194                                     State and Main   2000-08-26
# 42195  42195                                      Guilty as Sin   1993-06-04
# 42196  42196                                    Into the Mirror   2003-08-14
# 42197  42197                                        Gopi Kishan   1994-12-02
# 42198  42198                                     Eşrefpaşalılar   2010-03-05
# 42199  42199                                    The Ghost Train   1941-05-03
# 42200  42200                           Mermaids: The Body Found   2011-03-19
# 42201  42201                                            Knuckle   2011-01-21
# 42202  42202  The Super Dimension Fortress Macross II: Lover...   1992-05-21
# 42203  42203                                            Spliced         2002
#
#        box_office_revenue  runtime  \
# 0              14010832.0     98.0
# 1                     NaN    110.0
# 2                     NaN    106.0
# 3                     NaN     86.0
# 4                     NaN     93.0
# 5              10161099.0    137.0
# 6                     NaN      NaN
# 7                     NaN      NaN
# 8             102272727.0    139.0
# 9                     NaN    108.0
# 10                    NaN     82.0
# 11                    NaN      NaN
# 12             29381649.0    123.0
# 13                    NaN      NaN
# 14                    NaN    168.0
# 15                    NaN    180.0
# 16                    NaN    110.0
# 17                    NaN     91.0
# 18                    NaN      NaN
# 19                    NaN    100.0
# 20                    NaN     10.0
# 21                    NaN    101.0
# 22             34331783.0    109.0
# 23             11091868.0    103.0
# 24              3416846.0     97.0
# 25               172055.0     87.0
# 26              3960327.0     98.0
# 27                    NaN      NaN
# 28                    NaN    125.0
# 29                    NaN     90.0
# ...                   ...      ...
# 42174                 NaN      NaN
# 42175            683131.0     91.0
# 42176                 NaN     91.0
# 42177                 NaN    100.0
# 42178                 NaN     66.0
# 42179                 NaN     97.0
# 42180                 NaN     70.0
# 42181           2158775.0    118.0
# 42182         288752301.0    117.0
# 42183                 NaN    104.0
# 42184                 NaN     74.0
# 42185                 NaN    136.0
# 42186                 NaN    108.0
# 42187                 NaN     72.0
# 42188                 NaN     90.0
# 42189                 NaN      9.0
# 42190                 NaN     82.0
# 42191          15369573.0    100.0
# 42192                 NaN     59.0
# 42193                 NaN      NaN
# 42194           6944471.0    106.0
# 42195          22886222.0    107.0
# 42196                 NaN    113.0
# 42197                 NaN      NaN
# 42198           1847671.0      NaN
# 42199                 NaN     82.0
# 42200                 NaN    120.0
# 42201                 NaN     96.0
# 42202                 NaN    150.0
# 42203                 NaN     86.0
#
#                                                   genres  \
# 0      ["Space western", "Horror", "Supernatural", "T...
# 1      ["Erotic thriller", "Psychological thriller", ...
# 2                                              ["Drama"]
# 3      ["Adventure", "Fantasy", "World cinema", "Fami...
# 4      ["Romance Film", "Ensemble Film", "Comedy-dram...
# 5      ["Epic", "War film", "Costume drama", "Drama",...
# 6                                             ["Comedy"]
# 7      ["Short Film", "Science Fiction", "Family Film...
# 8      ["Children's/Family", "Children's Fantasy", "C...
# 9                                                     []
# 10     ["Romance Film", "Comedy", "Indie", "Romantic ...
# 11                                      ["Romance Film"]
# 12           ["Coming of age", "Crime Fiction", "Drama"]
# 13                             ["Comedy", "Family Film"]
# 14                                            ["Action"]
# 15     ["Romance Film", "Musical", "Drama", "Bollywoo...
# 16                                             ["Drama"]
# 17     ["Romance Film", "Comedy", "Indie", "Romantic ...
# 18                                             ["Drama"]
# 19                                            ["Comedy"]
# 20                   ["Indie", "Fan film", "Short Film"]
# 21                            ["Comedy", "Black comedy"]
# 22     ["Adventure Comedy", "Indie", "Cult", "Slapsti...
# 23     ["Comedy", "Comedy-drama", "Sports", "Drama", ...
# 24     ["Crime Fiction", "Action/Adventure", "Action"...
# 25     ["Indie", "Ensemble Film", "Drama", "Comedy-dr...
# 26         ["Romance Film", "Comedy", "Romantic comedy"]
# 27                             ["Romance Film", "Drama"]
# 28     ["Costume drama", "Biopic [feature]", "Black-a...
# 29     ["Documentary", "Culture & Society", "Biography"]
# ...                                                  ...
# 42174                                ["Drama", "Action"]
# 42175  ["Romance Film", "Black-and-white", "Family Dr...
# 42176                      ["Comedy", "Romantic comedy"]
# 42177  ["Comedy-drama", "Gay Interest", "Drama", "Rom...
# 42178  ["Detective fiction", "Black-and-white", "Crim...
# 42179     ["Drama", "Marriage Drama", "Film adaptation"]
# 42180                    ["Romance Film", "Silent film"]
# 42181  ["Romance Film", "Gay Interest", "Biographical...
# 42182  ["Romance Film", "Comedy of manners", "Comedy"...
# 42183  ["Romance Film", "Fantasy Comedy", "Indie", "C...
# 42184                       ["Black-and-white", "Drama"]
# 42185                                          ["Drama"]
# 42186  ["Documentary", "World cinema", "Horror", "Cul...
# 42187                                    ["Documentary"]
# 42188  ["Crime Thriller", "Action/Adventure", "Action...
# 42189                                     ["Short Film"]
# 42190                          ["Drama", "World cinema"]
# 42191  ["Comedy", "Science Fiction", "Adventure", "Al...
# 42192                  ["B-movie", "Horror", "Thriller"]
# 42193  ["Romance Film", "Drama", "Science Fiction", "...
# 42194                  ["Comedy", "Americana", "Parody"]
# 42195  ["Erotic thriller", "Courtroom Drama", "Crime ...
# 42196                                         ["Horror"]
# 42197             ["Comedy", "Crime", "Drama", "Action"]
# 42198                           ["Comedy film", "Drama"]
# 42199  ["Comedy", "Supernatural", "Crime Fiction", "T...
# 42200                                          ["Drama"]
# 42201      ["Documentary", "Drama", "Biographical film"]
# 42202  ["Drama", "Japanese Movies", "Short Film", "An...
# 42203          ["Teen", "Horror", "Slasher", "Thriller"]
#
#                                                  summary
# 0      Set in the second half of the 22nd century, th...
# 1      A series of murders of rich young women throug...
# 2      Eva, an upper class housewife, becomes frustra...
# 3      Every hundred years, the evil Morgana  returns...
# 4      Adam, a San Francisco-based artist who works a...
# 5      {{Plot|dateAct 1Act 2Act 3Act 4Act 5 Finally n...
# 6      Serap, a young actress with a strong, lively p...
# 7       The story starts as one of the robots flies i...
# 8      The film opens with Mary Poppins  perched in a...
# 9      Otto Brosowski, a communist miner, writes to t...
# 10     Jimmy ([[Hiroshi Watanabe  loves dinosaurs and...
# 11     The film opens with a simpleton from a small v...
# 12     A young 20-year-old named Jody  lives with his...
# 13     Shalini 'Shalu' lives a wealthy lifestyle with...
# 14     Professor Kurian Fernandez , a convict escapes...
# 15     Mary, an orphan lives in an orphanage run by n...
# 16     Anoop Chandran , is a famous writer and award ...
# 17     Perry is an English chemist working for a pain...
# 18     The film is the story of Yamuna  whose life is...
# 19     Archie Andrews, fifteen years after graduating...
# 20     An example of the film's comedic tone comes in...
# 21     Ruby and Claude Montgomery are a very insecure...
# 22     The film is a collision of three separate stor...
# 23     In the fictional farming village of Tlachtlán,...
# 24     A Japanese businessman sees a woman being grop...
# 25     The Great New Wonderful is a series of vignett...
# 26     Randy Bodek  is a rebellious college slacker, ...
# 27     Chandra Mukhi , a princess of a heavenly kingd...
# 28     The film focuses on the conflict between Maxim...
# 29     In the 1980s, video games were synonymous with...
# ...                                                  ...
# 42174  Vajram movie is about Devarajan , a Mafioso tu...
# 42175  Anital Halstead  goes to see a magic act perfo...
# 42176  A daytime soap opera star has to deal with his...
# 42177  The film deals with the myriad complications a...
# 42178  The film begins with a title card describing H...
# 42179  Sophie and Otto Bentwood are a middle-aged, mi...
# 42180  The story is set in Africa. Two rival European...
# 42181  The film opens with Oscar Wilde's 1882 visit t...
# 42182  Akeem Joffer , the prince and heir to the thro...
# 42183  Joe Morton stars in this dramatic comedy, set ...
# 42184  Yvonne Valbret  is a Parisian belle who poses ...
# 42185  The film revolves around Madhavan Nair who unk...
# 42186  At the beginning, there is a scene with a dog ...
# 42187  In September 1998, at the end of the Balkan wa...
# 42188  Charlie Daines , is a morphine-addicted detect...
# 42189  The story begins with young Bobby and his frie...
# 42190  A story about a young man who inherits a broke...
# 42191  The space armada from Mars, known as the Imper...
# 42192  Insane archaeologist Professor Andrew Forbes  ...
# 42193  Kalai Arasi' is a well-blended story of romanc...
# 42194  Havoc is wrought on the inhabitants of a small...
# 42195  Jennifer Haines  is an up-and-coming Chicago a...
# 42196  After accidentally causing the death of his pa...
# 42197  Kishan  killed a man in his childhood when the...
# 42198  The film is about two friends, Tayyar , a mafi...
# 42199  {{plot}} The film opens with a Great Western e...
# 42200  Two former National Oceanic Atmospheric Admini...
# 42201  {{No plot}} This film follows 12 years in the ...
# 42202  The story takes place in the year 2092,The Sup...
# 42203  The movie is about a teenage girl who loves ho...
#
# [42204 rows x 7 columns]
